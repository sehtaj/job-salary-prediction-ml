# %% [markdown]
# # Exploratory Data Analysis\n
# \n
# This notebook loads the salary dataset and performs a simple first-pass inspection.

# %%
# Import pandas for data loading and analysis\n
import pandas as pd

# %%
# Load the dataset from the raw data folder into a DataFrame\n
df = pd.read_csv("../data/raw/salary_data_cleaned.csv")

# %%
# Display the first 5 rows to preview the dataset\n
df.head()

# %%
# Display dataset information such as column names, non-null counts, and data types\n
df.info()

# %%
# Display summary statistics for the numerical columns\n
df.describe()
